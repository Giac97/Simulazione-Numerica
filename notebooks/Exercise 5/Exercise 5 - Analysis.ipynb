# %% [markdown]
# # Exercise 5

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyvista as pv

# %%
pts = np.loadtxt("psinew.dat", unpack = True)

# %%
N, r_avg, r_err = np.loadtxt("r_avg.dat", unpack = True)

# %%
plt.axhline(5, color = "red", label = r"$\langle r\rangle_{analytic}$ ")
plt.errorbar(N, r_avg, r_err, color = "blue", linewidth =1, elinewidth = 0.8,ecolor = "blue", label = r"$\langle r\rangle_{M(RT)^2}$ ")
plt.legend()
plt.xlim((0, 100))
# Out:
# (0.0, 100.0)

# %%
plt.plot(r_err[1:])
plt.plot(-r_err[1:])
