# %% [markdown]
# # Exercise 4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
block, press, press2, err_press = np.loadtxt("output_press.dat", unpack = True)

# %%
plt.errorbar(block, press, err_press, elinewidth = 0.7, color = "k")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
block, press_solid, press2_solid, err_press_solid = np.loadtxt("output_press_solid.dat", unpack = True)

# %%
plt.errorbar(block, press_solid, err_press_solid, color = "k", elinewidth = 1,linewidth = 0.7)
# Out:
# <ErrorbarContainer object of 3 artists>
